# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviocorrea-usa/Repo_FlavioCorrea/blob/CSCI-E-184/PSET_Data_Collection_and_Management_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSCI S-184 PSET 3
# ## Data Collection and Management Exercise
# ### Authors:
#
# * Mostafa Galal
# * Samantha Kanny
# * Flavio Correa
# * Zuri Hunter
# * Brian Durst
# * Jeff Winchell

# %% [markdown]
# # Introduction
#
# *Briefly describe your chosen social media platform, trending topic, and why.*

# %% [markdown]
# # Data Collection
#
# *Detail the process you went through to collect the data. Include the
# methodology used, the number of posts/comments collected, and any challenges encountered during the process.*

# %% [markdown]
# # Data Examination
#
# *Present your findings from the examination of the data. Use visualizations where possible.*
#
# *Data Overview*
# *   *How many posts or comments have you collected?*
# *   *What kind of information does each post or commentcontain (For example, text, date, username, likes, retweets, etc.)?*
#
# *Identify Patterns*
# *  *Try to identify patterns in the data.*
# *  *Are there certain phrases or keywords that come up frequently?*
#
# *Make Observations*
# *  *Note any interestng or unexpected observatons.*
#
# *Potential Issues*
# *   *Pay atention to any potential issues with the data.*
# *   *This could bemissing values (For example, a post without a date or a comment without a username),outliers (For example, a post with an unusually high number of likes), or any signs of bias(For example, are all the posts you collected from a specific demographic?).*
#
# *Data Examination Grading Rubric*
# *   *Successfully collected data related to the specified trending topic (20 points)*
# *   *Demonstrated an understanding of the ethical considerations and obtained data appropriately (10 points)*
# *   *Explained the data collecton methodology clearly and thoroughly (10 points)*

# %% [markdown]
# # Ethical Analysis
# *Provide your responses to the ethical consideration questions. Be thorough and critical in your analysis.*
#
# *   *How did you handle consent issues while collecting this data?*
# *   *Considering that these are public posts, do you think obtaining individual consent was necessary? Why or why not?*
# *   *How did you ensure the privacy of the individuals whose posts/comments you collected?*
# *   *Could the data you collected be used in a way that could harm individuals or groups?*
# *   *If yes, how can this be mitigated?*
# *   *How transparent was your data collection process? Could others replicate it and arrive atthe same data set?*
# *   *If you had to share this data with others, what precautions would you take?*
# *   *Could others replicate it and arrive at the same data set?*
# *   *If you had to share this data with others, what precautions would you take?*
# *   *Provided a thorough discussion on the issue of consent in the data collection process (10 points)*
# *   *Provided a clear position on the issue and justified it well (10 points)*

# %% [markdown]
# # Conclusion
#
# *Summarize what you learned from the assignment. Reflect on the ethical
# implications of data collection from social media and how it can be improved to respect privacy and ensure fairness.*
